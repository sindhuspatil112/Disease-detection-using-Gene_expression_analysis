# %%
# ================================
# Validate Breast Model on Ovarian Dataset
# ================================

import pandas as pd
import joblib
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# ----------------------------
# Step 1️⃣: Load breast model
# ----------------------------
model = joblib.load("../../models/breast_model.pkl")
print("✅ Loaded model: breast_model.pkl")

# ----------------------------
# Step 2️⃣: Load ovarian dataset
# ----------------------------
df_ov = pd.read_csv("../../data/labeled/ovarian_labeled.csv")
print(f"✅ Ovarian dataset loaded: {df_ov.shape[0]} samples, {df_ov.shape[1]-1} genes")

X_ov = df_ov.drop(columns=["status"])
y_ov = df_ov["status"]

# ----------------------------
# Step 3️⃣: Match genes with breast model
# ----------------------------
# Load top genes from breast biomarkers file
top_genes = pd.read_csv("../../outputs/metrics/breast_top_genes.csv")["Gene"].tolist()

# Select only common genes
common_genes = [g for g in top_genes if g in X_ov.columns]
print(f"🧬 Using {len(common_genes)} common top genes for cross-prediction")

X_ov_subset = X_ov[common_genes]

# ----------------------------
# Step 4️⃣: Predict using breast model
# ----------------------------
y_pred = model.predict(X_ov_subset)
y_prob = model.predict_proba(X_ov_subset)[:, 1]

# ----------------------------
# Step 5️⃣: Evaluate performance
# ----------------------------
acc = accuracy_score(y_ov, y_pred)
roc = roc_auc_score(y_ov, y_prob)

print(f"\n✅ Cross-disease Prediction (Breast → Ovarian):")
print(f"Accuracy: {acc:.4f}")
print(f"ROC-AUC: {roc:.4f}")
print("\nClassification Report:")
print(classification_report(y_ov, y_pred))

# ----------------------------
# Step 6️⃣: Save results
# ----------------------------
results = pd.DataFrame({
    "true_label": y_ov,
    "predicted_label": y_pred,
    "predicted_prob": y_prob
})
results.to_csv("../outputs/metrics/breast_to_ovarian_predictions.csv", index=False)
print("💾 Saved predictions to ../outputs/metrics/breast_to_ovarian_predictions.csv")
# Out:
# ✅ Loaded model: breast_model.pkl
# ✅ Ovarian dataset loaded: 63 samples, 22189 genes
# 🧬 Using 20 common top genes for cross-prediction
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 39
#      34 X_ov_subset = X_ov[common_genes]
#      36 # ----------------------------
#      37 # Step 4️⃣: Predict using breast model
#      38 # ----------------------------
# ---> 39 y_pred = model.predict(X_ov_subset)
#      40 y_prob = model.predict_proba(X_ov_subset)[:, 1]
#      42 # ----------------------------
#      43 # Step 5️⃣: Evaluate performance
#      44 # ----------------------------
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - A1CF
# - A2M
# - A4GALT
# - A4GNT
# - AAAS
# - ...

# %%
# =======================================
# Cross-Disease Validation: Breast → Ovarian
# =======================================
import pandas as pd
import joblib
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# ----------------------------
# Step 1️⃣: Load model & dataset
# ----------------------------
model = joblib.load("../../models/breast_model.pkl")
print("✅ Loaded model: breast_model.pkl")

df_ov = pd.read_csv("../../data/labeled/ovarian_labeled.csv")
print(f"✅ Ovarian dataset loaded: {df_ov.shape[0]} samples, {df_ov.shape[1]-1} genes")

X_ov = df_ov.drop(columns=["status"])
y_ov = df_ov["status"]

# ----------------------------
# Step 2️⃣: Load top genes (from breast)
# ----------------------------
top_genes = pd.read_csv("../../outputs/metrics/breast_top_genes.csv")["Gene"].tolist()
print(f"🧬 Found {len(top_genes)} top genes from breast model")

# Normalize column names (case-insensitive)
X_ov.columns = [c.strip().upper() for c in X_ov.columns]
top_genes_upper = [g.strip().upper() for g in top_genes]

# Find overlapping and missing genes
common_genes = [g for g in top_genes_upper if g in X_ov.columns]
missing_genes = [g for g in top_genes_upper if g not in X_ov.columns]
print(f"✅ Using {len(common_genes)} overlapping genes")
print(f"⚠️ Missing {len(missing_genes)} genes (filled with zeros)")

# Create aligned feature set
X_aligned = pd.DataFrame()

# Add all top genes in correct order
for gene in top_genes_upper:
    if gene in X_ov.columns:
        X_aligned[gene] = X_ov[gene]
    else:
        X_aligned[gene] = 0  # Fill missing genes with zero expression

print(f"🧩 Final aligned shape for prediction: {X_aligned.shape}")

# ----------------------------
# Step 3️⃣: Predict
# ----------------------------
y_pred = model.predict(X_aligned)
y_prob = model.predict_proba(X_aligned)[:, 1]

# ----------------------------
# Step 4️⃣: Evaluate
# ----------------------------
acc = accuracy_score(y_ov, y_pred)
roc = roc_auc_score(y_ov, y_prob)

print(f"\n✅ Cross-disease Prediction (Breast → Ovarian):")
print(f"Accuracy: {acc:.4f}")
print(f"ROC-AUC: {roc:.4f}")
print("\nClassification Report:")
print(classification_report(y_ov, y_pred))

# ----------------------------
# Step 5️⃣: Save results
# ----------------------------
import os
os.makedirs("../../outputs/metrics", exist_ok=True)

results = pd.DataFrame({
    "true_label": y_ov,
    "predicted_label": y_pred,
    "predicted_prob": y_prob
})
results.to_csv("../../outputs/metrics/breast_to_ovarian_predictions.csv", index=False)
print("💾 Saved predictions to ../../outputs/metrics/breast_to_ovarian_predictions.csv")
# Out:
# ✅ Loaded model: breast_model.pkl
# ✅ Ovarian dataset loaded: 63 samples, 22189 genes
# 🧬 Found 20 top genes from breast model
# ✅ Using 20 overlapping genes
# ⚠️ Missing 0 genes (filled with zeros)
# 🧩 Final aligned shape for prediction: (63, 20)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 51
#      46 print(f"🧩 Final aligned shape for prediction: {X_aligned.shape}")
#      48 # ----------------------------
#      49 # Step 3️⃣: Predict
#      50 # ----------------------------
# ---> 51 y_pred = model.predict(X_aligned)
#      52 y_prob = model.predict_proba(X_aligned)[:, 1]
#      54 # ----------------------------
#      55 # Step 4️⃣: Evaluate
#      56 # ----------------------------
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - A1CF
# - A2M
# - A4GALT
# - A4GNT
# - AAAS
# - ...
